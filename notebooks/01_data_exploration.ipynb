# %% [markdown]
# # 01. Astronomical Data Exploration & Photometric Visualizations
# This notebook demonstrates loading ZTF and ASAS-SN alerts, parsing irregular multi-band photometry, and visualizing astronomical image postage stamps.

# %%
import sys; sys.path.append('..')
from src.data.dataset_builder import generate_benchmark_events
from dashboard.plots import plot_multiband_lightcurve, plot_cutout_channels

events = generate_benchmark_events(num_known=10, num_anomalies=5)
print(f'Loaded {len(events)} sample astronomical events.')
sample = events[0]
print(f'Event {sample.object_id} | Class: {sample.true_label}')
