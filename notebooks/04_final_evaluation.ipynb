# %% [markdown]
# # 04. Final Evaluation, Ablations & Bootstrap Confidence Intervals (Stages 8 & 9)
# Running the full research evaluation suite: Anomaly AUROC, FDR at 95% TPR, ECE/Brier calibration, Groundedness ratio, and Bayesian Information Gain.

# %%
import sys; sys.path.append('..')
from src.pipeline.acei_pipeline import ACEIPipeline, run_pipeline_demo

run_pipeline_demo()
